# %%
#we will use pillow library here
from PIL import Image

# %%
i = Image.open('example.jpg')

# %%
#i.show()
#i

# %%
type(i)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
i.size
# Out:
# (1993, 1257)

# %%
i.filename
# Out:
# 'example.jpg'

# %%
i.format_description
# Out:
# 'JPEG (ISO 10918)'
